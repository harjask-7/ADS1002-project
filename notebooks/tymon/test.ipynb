# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import glob
from scipy.stats import linregress
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# select demand for victoria and sort in order of date
demand_tas = glob.glob("/Users/Coder/Desktop/ADS1002-project/data/raw/demand/*_TAS1.csv")
demand_tas.sort()
demand_NSW = glob.glob("/Users/Coder/Desktop/ADS1002-project/data/raw/demand/*_NSW1.csv")
demand_NSW.sort()

# read demand data files and combine
df_list = [pd.read_csv(f) for f in demand_NSW]
if df_list:
    demand_df = pd.concat(df_list, ignore_index=True)
    #print("CSV files loaded")
else:
    print("No CSV files were loaded.")

# rename and drop columns
demand_df = demand_df.rename(columns={
    "SETTLEMENTDATE": "Datetime",
    "TOTALDEMAND": "Total Demand",
    "REGION": "State"
})

# Find the minimum and maximum RRP
min_rrp = demand_df['RRP'].min()
max_rrp = demand_df['RRP'].max()

# Print the results
print(f"Minimum RRP: {min_rrp}")
print(f"Maximum RRP: {max_rrp}")


# Sort by RRP in descending order
sorted_df = demand_df.sort_values(by="RRP", ascending=False)

# Print the top rows (highest RRP first)
print(sorted_df.head(10))  # change 10 to however many rows you want
# Out:
# Minimum RRP: -264.31
# Maximum RRP: 14000.0
#        State             Datetime  Total Demand       RRP PERIODTYPE
# 300027  NSW1  2017/02/10 18:00:00      13528.94  14000.00      TRADE
# 300026  NSW1  2017/02/10 17:30:00      13526.26  13966.67      TRADE
# 275740  NSW1  2015/09/23 18:30:00       9962.61  13419.89      TRADE
# 300025  NSW1  2017/02/10 17:00:00      13985.87  12914.63      TRADE
# 194375  NSW1  2011/02/01 16:00:00      14525.73  12136.17      TRADE
# 194374  NSW1  2011/02/01 15:30:00      14337.52  12072.50      TRADE
# 295990  NSW1  2016/11/18 15:30:00      10246.02  11700.63      TRADE
# 299832  NSW1  2017/02/06 16:30:00      13586.77  11692.09      TRADE
# 194422  NSW1  2011/02/02 15:30:00      14403.24  10417.07      TRADE
# 194423  NSW1  2011/02/02 16:00:00      14417.03  10243.51      TRADE
