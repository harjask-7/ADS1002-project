# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt

# read master data
master_df = pd.read_csv(
    r"C:\Users\rohan\Downloads\master_data (1).csv",
    skipinitialspace=True,
    low_memory=False,
    parse_dates=['Datetime']
)



state_counts = master_df['State'].value_counts()
print(state_counts)
# Out:
# State
# VIC    377681
# NSW    349699
# QLD    349294
# SA     349176
# TAS    254867
# Name: count, dtype: int64

# %% [markdown]
# ***Linear Regression work***

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf

# Work on a copy; rename to clean column names for the formula
df = master_df.copy().rename(columns={
    "Total Demand": "Demand",
    "Precipitation (mm)": "Precipitation"
})

rows = []

for state in df["State"].unique():
    sub = df.loc[df["State"] == state, ["Demand", "Precipitation", "State"]].dropna(subset=["Demand", "Precipitation"])

    # we find the ols
    model = smf.ols("Demand ~ Precipitation", data=sub).fit()
    slope = model.params["Precipitation"]  

    rows.append({
        "State": state,
        "Intercept": model.params["Intercept"],
        "Slope(Precipitation)": slope,
        "R2": model.rsquared
    })

    print(f"{state}: Intercept={model.params['Intercept']:.2f}, "
          f"Slope={slope:.4f}, R²={model.rsquared:.4f}")

per_state_precip_ols = pd.DataFrame(rows).sort_values("State").reset_index(drop=True)
per_state_precip_ols
# Out:
# NSW: Intercept=8348.37, Slope=-13.0611, R²=0.0032
# QLD: Intercept=5779.33, Slope=-5.2217, R²=0.0016
# SA: Intercept=1446.91, Slope=-5.1805, R²=0.0022
# TAS: Intercept=1134.38, Slope=-1.4918, R²=0.0009
# VIC: Intercept=5489.78, Slope=-17.8723, R²=0.0036
#   State    Intercept  Slope(Precipitation)        R2
# 0   NSW  8348.366095            -13.061088  0.003248
# 1   QLD  5779.333649             -5.221746  0.001587
# 2    SA  1446.910927             -5.180543  0.002212
# 3   TAS  1134.379143             -1.491753  0.000893
# 4   VIC  5489.780684            -17.872315  0.003554

# %% [markdown]
# Interpretation:
# R² is very small, from 0.0009 to 0.0036. We can conclude rain alone explains around 0.4% of demand variation. Thus rain alone isnt a very useful indicator to demand.
#
# Slopes are negative in all states. More rain is weakly associated with slightly lower demand—likely reflecting cooler/cloudier conditions reducing cooling load.
# As rain increases, it has a weak associatino with slightly lower demand, which could inidicate cooler/wetter condtions reducucing demand. Demand coudl then be said to be a factor of heating not cold/
#
# The intercepts from (~1,100–8,300 MW) reflect each state’s baseline demand level in the regression.
#
# Takeaway: precipitation has a very small effect on demand when used by itself. We will peform multivariable regression for a better regression

# %%
import pandas as pd
import statsmodels.formula.api as smf

# ---- 1) Clean names & prep time features ----
df = master_df.copy().rename(columns={
    "Total Demand": "Demand",
    "Air Temp (C)": "Temperature",   # keep original "Precipitation (mm)" name
})

# time fields
df["Datetime"] = pd.to_datetime(df["Datetime"], errors="coerce")
df = df.dropna(subset=["Datetime", "Demand", "Temperature", "Precipitation (mm)"]).sort_values("Datetime")
df["hour"]  = df["Datetime"].dt.hour
df["month"] = df["Datetime"].dt.month
df["year"]  = df["Datetime"].dt.year

# categories for fixed effects
df["State"] = df["State"].astype("category")

# ---- 2) Multivariate OLS with precipitation + temp curvature + calendar + state FEs ----
formula = (
    "Demand ~ Q('Precipitation (mm)') "
    "+ Temperature + I(Temperature**2) "
    "+ C(hour) + C(month) + C(year) "
    "+ C(State)"
)

model = smf.ols(formula, data=df).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Demand   R-squared:                       0.948
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                 5.029e+05
# Date:                Sat, 04 Oct 2025   Prob (F-statistic):               0.00
# Time:                        17:59:54   Log-Likelihood:            -1.3158e+07
# No. Observations:             1668877   AIC:                         2.632e+07
# Df Residuals:                 1668815   BIC:                         2.632e+07
# Df Model:                          61
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                9002.3975      6.454   1394.929      0.000    8989.749    9015.046
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np
import pandas as pd


df = master_df.copy().rename(columns={
    "Total Demand": "Demand",
    "Air Temp (C)": "Temperature",
    "Humidity (%)": "Humidity",
    "Wind Speed (km/h)": "WindSpeed", 
})


# Parsing datetimes and creating hour,month,year
df["Datetime"] = pd.to_datetime(df["Datetime"], errors="coerce")
df = df.dropna(subset=["Datetime", "Demand", "Temperature", "Humidity", "Precipitation (mm)", "State"]).sort_values("Datetime")

df["Hour"]  = df["Datetime"].dt.hour
df["Month"] = df["Datetime"].dt.month
df["Year"]  = df["Datetime"].dt.year

#Building Ml table
feature_cols = ["Temperature", "Humidity", "Precipitation (mm)", "WindSpeed", "Hour", "Month", "Year", "State"]
use_cols = ["Datetime", "Demand"] + feature_cols
df_ml = df.filter(items=use_cols).copy()   # no KeyError if some are missing

df_ml = pd.get_dummies(df_ml, columns=["State"], drop_first=True)  # one-hot State

#Splitting the data
df_ml = df_ml.sort_values("Datetime")
split_idx = int(len(df_ml) * 0.90)  #We only use the first 90% of data so we dont use future data
train, test = df_ml.iloc[:split_idx].copy(), df_ml.iloc[split_idx:].copy() 

X_train = train.drop(columns=["Datetime", "Demand"])
y_train = train["Demand"].values
X_test  = test.drop(columns=["Datetime", "Demand"])
y_test  = test["Demand"].values


rf = RandomForestRegressor(
    n_estimators=200,
    max_depth=15,
    random_state=42,
    n_jobs=-1
)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

train_pred = rf.predict(X_train)
test_pred  = y_pred  
#We calculate RMSE, R^2, and MAE. note: 
#RMSE, the measure which linear regression aims to minimise, 
#MAE, similarly an error metric we want to minimise
scores = pd.DataFrame({
    "R^2": {
        "train": r2_score(y_train, train_pred),
        "test":  r2_score(y_test,  test_pred),
    },
    "RMSE": {
        "train": mean_squared_error(y_train, train_pred, squared=False),
        "test":  mean_squared_error(y_test,  test_pred,  squared=False),
    },
    "MAE": {
        "train": mean_absolute_error(y_train, train_pred),
        "test":  mean_absolute_error(y_test,  test_pred),
    },
})x`x

print(scores.round(2))

# --- 7) Feature importance (top 10) ---
feat_importance = pd.Series(rf.feature_importances_, index=X_train.columns).sort_values(ascending=False)
print("\nTop 10 features:\n", feat_importance.head(10))
# Out:
# C:\Users\rohan\anaconda\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# C:\Users\rohan\anaconda\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#         R^2    RMSE     MAE
# train  0.98  364.11  247.17
# test   0.98  388.39  257.34
#
# Top 10 features:
#  WindSpeed      0.444313
# State_VIC      0.294949
# State_QLD      0.178294
# Hour           0.046351
# Temperature    0.014265
# Year           0.011712
# Month          0.004297
# State_SA       0.002668
# Humidity       0.001552
# State_TAS      0.001267
# dtype: float64

# %%
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler

# y must align to X
y = df_ml.loc[X.index, "Demand"].to_numpy()

# Chronological split: last 20% as test
split = int(len(X) * 0.8)
X_train, X_test = X.iloc[:split], X.iloc[split:]
y_train, y_test = y[:split], y[split:]


# Scale using train stats only
scaler = StandardScaler(with_mean=True, with_std=True)
Xs_train = scaler.fit_transform(X_train)
Xs_test  = scaler.transform(X_test)

alfas = np.logspace(-2, 2, num=21)
ridge_training_score = np.zeros_like(alfas, dtype=float)
ridge_rsquared       = np.zeros_like(alfas, dtype=float)

for i, alpha in enumerate(alfas):
    ridge = Ridge(alpha=alpha, random_state=1235)
    ridge.fit(Xs_train, y_train)                        
    ridge_training_score[i] = ridge.score(Xs_train, y_train)
    preds = ridge.predict(Xs_test)
    ridge_rsquared[i] = r2_score(y_test, preds)         


plt.figure(figsize=(7,4))
plt.scatter(alfas, ridge_training_score, label='Training R²')
plt.scatter(alfas, ridge_rsquared, label='Testing R²')
plt.xscale('log')
plt.xlim(0.01, 100)
plt.title('Ridge regularisation (chronological split)')
plt.xlabel('alpha'); plt.legend(); plt.show()

opt_pos = np.argmax(ridge_rsquared)
opt_alpha = alfas[opt_pos]
print(f"Optimal alpha: {opt_alpha:.3f}")
print(f"Train R² @opt: {ridge_training_score[opt_pos]:.3f}")
print(f"Test  R² @opt: {ridge_rsquared[opt_pos]:.3f}")
# Out:
# Optimal alpha: 0.010
# Train R² @opt: 0.272
# Test  R² @opt: 0.279

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# match data names---
df = master_df.copy().rename(columns={
    "Air Temp (C)": "Temperature",
    "Humidity (%)": "Humidity",
    "Wind Speed (km/h)": "Wind Speed (km/h)",  # keep original label
    "Total Demand": "Demand",                  # <- add this if your column is 'Total Demand'
})

# Time fields
df["Datetime"] = pd.to_datetime(df["Datetime"], errors="coerce")
df = df.dropna(subset=["Datetime", "Temperature", "Humidity", "Precipitation (mm)", "Demand"]).sort_values("Datetime")
df["Hour"]  = df["Datetime"].dt.hour
df["Month"] = df["Datetime"].dt.month
df["Year"]  = df["Datetime"].dt.year

# Temperature polynomials
df["t2"] = df["Temperature"]**2
df["t3"] = df["Temperature"]**3

# --- 2) Select target ---
features = ["Temperature", "t2", "t3", "Precipitation (mm)", "Humidity", "Wind Speed (km/h)", "Hour", "Month", "Year"]
target   = "Demand"

# One-hot encode (no categoricals here, but harmless) and drop missing
df_ml = pd.get_dummies(df[features + [target]], drop_first=True).dropna()

X = df_ml.drop(columns=[target])
y = df_ml[target].values

tail_n = 100_000
X, y = X.tail(tail_n), y[-tail_n:]

# --- 3) Chronological split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Standardise
mu, sigma = X_train.mean(), X_train.std().replace(0, 1)
X_train_n = (X_train - mu) / sigma
X_test_n  = (X_test  - mu) / sigma

# --- 4) Lasso 
alfas = np.logspace(-2, 2, num=21)  # 0.01 ... 100
lasso_training_score = np.zeros_like(alfas, dtype=float)
lasso_rsquared       = np.zeros_like(alfas, dtype=float)

for idx, alfa in enumerate(alfas):
    lasso = Lasso(alpha=alfa, max_iter=10000, random_state=42)
    lasso.fit(X_train_n, y_train)
    lasso_training_score[idx] = lasso.score(X_train_n, y_train)
    preds = lasso.predict(X_test_n)
    lasso_rsquared[idx] = r2_score(y_test, preds)

# --- 5) Plot train/test R² vs alpha (log x-axis) ---
plt.figure(figsize=(7,4))
plt.scatter(alfas, lasso_training_score, label='Training score')
plt.scatter(alfas, lasso_rsquared,       label='Testing score')
plt.xscale('log'); plt.xlim(0.01, 100)
plt.title('Lasso regularisation')
plt.xlabel('alpha'); plt.legend(loc='best'); plt.tight_layout()
plt.show()

# --- 6) Report optimal alpha & scores ---
opt_alfa_pos = int(np.argmax(lasso_rsquared))
opt_alfa = alfas[opt_alfa_pos]
print(f'Optimal alpha is {opt_alfa:.3f}')
print(f'Training score with optimal alpha is {lasso_training_score[opt_alfa_pos]:.3f}')
print(f'Testing  score with optimal alpha is {lasso_rsquared[opt_alfa_pos]:.3f}')
# Out:
# Optimal alpha is 63.096
# Training score with optimal alpha is 0.257
# Testing  score with optimal alpha is 0.361

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

eval_df = pd.DataFrame(index=X_test.index)
eval_df["Datetime"]  = df_ml.loc[X_test.index, "Datetime"].values
eval_df["Actual"]    = y_test                         # <-- use y_test directly
eval_df["Predicted"] = y_pred                         # <-- model outputs
eval_df = eval_df.sort_values("Datetime").set_index("Datetime")


# 2) Downsample to hourly means 
hourly = eval_df.resample("1H").mean()

# 3) Actual vs Predicted 
DAYS  = 15
start = pd.Timestamp("2019-07-01")
end   = start + pd.Timedelta(days=DAYS)
window = hourly.loc[start:end]

# shows R²
y_true = window["Actual"].to_numpy()
y_hat  = window["Predicted"].to_numpy()
R2     = r2_score(y_true, y_hat)

# Plotting graphs, axis and R²
plt.figure(figsize=(10,4))
plt.plot(window.index, window["Actual"],    label="Actual",    linewidth=1.5)
plt.plot(window.index, window["Predicted"], label="Predicted", linewidth=1.5)
plt.title(f"Demand — Actual vs Predicted ({start.date()} to {end.date()}, hourly mean)")
plt.xlabel("Datetime"); plt.ylabel("MW"); plt.legend()
plt.gca().text(0.01, 0.99, f"R²: {R2*100:.1f}%",
               transform=plt.gca().transAxes, va="top", ha="left",
               bbox=dict(facecolor="white", alpha=0.85, edgecolor="black"))
plt.tight_layout(); plt.show()

# 5) Residuals vs Fitted 
resid = eval_df["Actual"] - eval_df["Predicted"]
plt.figure(figsize=(6,4))
plt.scatter(eval_df["Predicted"], resid, s=4, alpha=0.25)
plt.axhline(0, color="k", lw=1)
plt.title("Residuals vs Fitted (test)")
plt.xlabel("Fitted (MW)"); plt.ylabel("Residual (MW)")
plt.tight_layout(); plt.show()
# Out:
# C:\Users\rohan\AppData\Local\Temp\ipykernel_31628\1515490554.py:14: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   hourly = eval_df.resample("1H").mean()

# %% [markdown]
# the actual vs prediducted has a accuracy of 83.6.
