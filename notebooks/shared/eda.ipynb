# %% [markdown]
# # Exploratory Data Analysis
#
# - data summarisation
# - data visualisation (graphs)
# - hypothesis (heatmaps)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

master = pd.read_csv("/Users/jiehni/monash/ads1002/ADS1002-project/data/processed/master_data.csv")

master.shape
master.info()
master.describe()
# Out:
# /var/folders/0d/qf_dfhwn3vjd4fvry35670240000gn/T/ipykernel_53822/3927990394.py:5: DtypeWarning: Columns (0,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   master = pd.read_csv("/Users/jiehni/monash/ads1002/ADS1002-project/data/processed/master_data.csv")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1680293 entries, 0 to 1680292
# Data columns (total 12 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   State               1331423 non-null  object
#  1   Datetime            1680293 non-null  object
#  2   Total Demand        1680293 non-null  float64
#  3   RRP                 1680293 non-null  float64
#  4   Precipitation (mm)  1322887 non-null  float64
#  5   Air Temp (C)        1330720 non-null  float64
#  6   Humidity (%)        1330531 non-null  float64
#  7   Wind Speed (km/h)   888695 non-null   float64
#  8   Precipitation       348870 non-null   object
#  9   Air Temp            348870 non-null   float64
#  10  Humidity            348870 non-null   float64
#  11  Wind Speed          348870 non-null   float64
# dtypes: float64(9), object(3)
# memory usage: 153.8+ MB
#        Total Demand           RRP  Precipitation (mm)  Air Temp (C)  \
# count  1.680293e+06  1.680293e+06        1.322887e+06  1.330720e+06
# mean   4.634921e+03  5.135311e+01        9.524851e-01  1.633730e+01
# std    2.828664e+03  1.896984e+02        3.959391e+00  5.950501e+00
# min    2.189000e+01 -1.000000e+03        0.000000e+00 -3.000000e-01
# 25%    1.427350e+03  2.348000e+01        0.000000e+00  1.210000e+01
# 50%    5.141140e+03  3.474000e+01        0.000000e+00  1.570000e+01
# 75%    6.573920e+03  5.470000e+01        2.000000e-01  2.000000e+01
# max    1.457986e+04  1.470000e+04        1.304000e+02  4.740000e+01
#
#        Humidity (%)  Wind Speed (km/h)       Air Temp       Humidity  \
# count  1.330531e+06      888695.000000  348870.000000  348870.000000
# mean   6.425850e+01          11.249568      20.813913      68.620237
# std    1.886982e+01           7.757995       5.126577      17.442522
# min    1.000000e+00           0.000000       3.000000       6.000000
# 25%    5.200000e+01           5.400000      17.300000      56.000000
# 50%    6.600000e+01           9.400000      21.200000      71.000000
# 75%    7.900000e+01          14.800000      24.500000      83.000000
# max    1.030000e+02          81.400000      41.100000     100.000000
#
#           Wind Speed
# count  348870.000000
# mean        7.169994
# std         5.108015
# min         0.000000
# 25%         3.600000
# 50%         7.600000
# 75%        11.200000
# max        48.200000

# %%
master.groupby("State")["Total Demand"].hist(bins=50, alpha=0.5, legend=True)
plt.show()

# %% [markdown]
# - Tasmania and South Australia are both very low demand states
#     - Tasmania peaks very sharply at around 1000-1200 MW, may be due to it being a smaller state with lower populaton
# - Queensland and Victoria are medium-high demand states
#     - Reflects a larger population
# - New South Wales has the highest demand for electricity
#
# Note: would be beneficial to analyse the states separately

# %%
sns.heatmap(master.corr(numeric_only=True), annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# Total Demand:
# - Strongest positive correlation with Air Temp (C)
# - Strongest negative correlation with Wind Speed (km/h)
# - Weak correlation with Humidity (%) and Precipitation (mm)
# - Almost no correlation with RRP
