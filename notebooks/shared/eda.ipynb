# %% [markdown]
# # Exploratory Data Analysis
#
# - data summarisation
# - data visualisation (graphs)
# - hypothesis (heatmaps)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

master = pd.read_csv("C:/Users/kohji/monash/ads1002/ADS1002-project/data/processed/master_data.csv")

master.shape
master.info()
master.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519736 entries, 0 to 519735
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   State               519736 non-null  object
#  1   Datetime            519736 non-null  object
#  2   Total Demand        519736 non-null  float64
#  3   RRP                 519736 non-null  float64
#  4   Precipitation (mm)  516568 non-null  float64
#  5   Air Temp (C)        519735 non-null  float64
#  6   Humidity (%)        519692 non-null  float64
#  7   Wind Speed (km/h)   453132 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 31.7+ MB
#         Total Demand            RRP  Precipitation (mm)  Air Temp (C)  \
# count  519736.000000  519736.000000       516568.000000  519735.00000
# mean     3113.283737      47.306484            0.928538      15.33262
# std      2630.699625     143.061833            3.980546       5.88885
# ...

# %%
master.groupby("State")["Total Demand"].hist(bins=50, alpha=0.5, legend=True)
plt.show()

# %% [markdown]
# - Tasmania and South Australia are both very low demand states
#     - Tasmania peaks very sharply at around 1000-1200 MW, may be due to it being a smaller state with lower populaton
# - Queensland and Victoria are medium-high demand states
#     - Reflects a larger population
# - New South Wales has the highest demand for electricity
#
# Note: would be beneficial to analyse the states separately

# %%
sns.heatmap(master.corr(numeric_only=True), annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# Total Demand:
# - Strongest positive correlation with Air Temp (C)
# - Strongest negative correlation with Wind Speed (km/h)
# - Weak correlation with Humidity (%) and Precipitation (mm)
# - Almost no correlation with RRP
